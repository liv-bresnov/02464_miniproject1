# %%
import numpy as np
standard=np.array([75.0, 76.25, 68.75, 56.25, 60.0, 53.75, 51.24999999999999, 41.25, 50.0, 55.00000000000001, 48.75, 53.75, 65.0, 70.0, 76.25])
increasing_rate=np.array([58.75, 66.25, 58.75, 45.0, 40.0, 31.25, 37.5, 41.25, 37.5, 46.25, 53.75, 60.0, 61.25000000000001, 73.75, 73.75])
pause=np.array([65.4320987654321, 60.49382716049383, 62.96296296296296, 50.617283950617285, 54.32098765432099, 38.2716049382716, 39.50617283950617, 43.20987654320987, 44.44444444444444, 55.55555555555556, 49.382716049382715, 55.55555555555556, 62.96296296296296, 58.0246913580247, 71.60493827160494])
working_mem_task=np.array([62.5, 60.0, 60.0, 50.0, 40.0, 41.25, 47.5, 40.0, 41.25, 43.75, 48.75, 45.0, 36.25, 47.5, 45.0])

# %%
import matplotlib.pyplot as plt
plt.plot(standard,label='Standard',marker='o')
plt.plot(increasing_rate,label='Increasing rate',marker='o')
plt.plot(pause,label='Pause',marker='o')
plt.plot(working_mem_task,label='Working memory task',marker='o')
plt.legend()
plt.ylabel('Percent recall')
plt.xlabel('Serial position')
plt.title('Free recall')
plt.show()
