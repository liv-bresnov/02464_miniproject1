# %%
import pandas as pd

# %% [markdown]
# # Merge and read csv_files

# %%
import pandas as pd
import glob
import os

# Path to your folder
folder_path = "csv.files"

# Find all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Read and concatenate all CSVs into one DataFrame
df = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)

# Show the combined DataFrame
print(df.head())
# Out:
#       Name Experiment  Trial                       Sequence  \
# 0    julie         FR      1  a t v h q c x b j i g r o p u
# 1    julie         FR      2  r a x t n q z o c p e s m u f
# 2    julie         FR      3  c n y d x e h u a j s i k r g
# 3    julie         FR      4  k m f h t q o l j z u y d r a
# 4    julie         FR      1  m a r q f o y n x z p b i e u
# ..     ...        ...    ...                            ...
# 155  julie  SR_ladida     16  p f l s q m b e j d r o h a c
# 156  julie  SR_ladida     17  z x g e k l v y d f q c a t p
# 157  julie  SR_ladida     18  i g l u m b e n q o x d c h p
# 158  julie  SR_ladida     19  n f z i e c a u d b g o q p x
# 159  julie  SR_ladida     20  a p i x u e j o d y t c l v r
#
#                               Recall
# 0              o p u b i g x a t d n
# 1        p e s m u f x r a s p q d z
# 2          j s i g r x z e b c h s u
# 3        k m f h u d l y e g c n p a
# 4    m a r q p i e u n x f o y z s t
# ..                               ...
# 155                        p f m l q
# 156                      z x g e k l
# 157                  i g l u m b e n
# 158                      n f z i e r
# 159                  a p i x u e j o
#
# [160 rows x 5 columns]

# %%
for s, r in zip(df["Sequence"], df["Recall"]):
    print(s.split(), r.split())
    for bogstav in s.split():
        print(bogstav)
# Out:
# ['a', 't', 'v', 'h', 'q', 'c', 'x', 'b', 'j', 'i', 'g', 'r', 'o', 'p', 'u'] ['o', 'p', 'u', 'b', 'i', 'g', 'x', 'a', 't', 'd', 'n']
# a
# t
# v
# h
# q
# c
# x
# b
# j
# i
# g
# r
# o
# p
# u
# ['r', 'a', 'x', 't', 'n', 'q', 'z', 'o', 'c', 'p', 'e', 's', 'm', 'u', 'f'] ['p', 'e', 's', 'm', 'u', 'f', 'x', 'r', 'a', 's', 'p', 'q', 'd', 'z']
# r
# a
# x
# t
# n
# q
# z
# o
# c
# p
# e
# s
# m
# u
# f
# ['c', 'n', 'y', 'd', 'x', 'e', 'h', 'u', 'a', 'j', 's', 'i', 'k', 'r', 'g'] ['j', 's', 'i', 'g', 'r', 'x', 'z', 'e', 'b', 'c', 'h', 's', 'u']
# c
# n
# y
# d
# x
# e
# h
# u
# a
# j
# s
# i
# k
# r
# g
# ['k', 'm', 'f', 'h', 't', 'q', 'o', 'l', 'j', 'z', 'u', 'y', 'd', 'r', 'a'] ['k', 'm', 'f', 'h', 'u', 'd', 'l', 'y', 'e', 'g', 'c', 'n', 'p', 'a']
# k
# m
# f
# h
# t
# q
# o
# l
# j
# z
# u
# y
# d
# r
# a
# ['m', 'a', 'r', 'q', 'f', 'o', 'y', 'n', 'x', 'z', 'p', 'b', 'i', 'e', 'u'] ['m', 'a', 'r', 'q', 'p', 'i', 'e', 'u', 'n', 'x', 'f', 'o', 'y', 'z', 's', 't']
# m
# a
# r
# q
# f
# o
# y
# n
# x
# z
# p
# b
# i
# e
# u
# ['r', 'y', 'n', 'h', 'z', 't', 'k', 'q', 'o', 'j', 'm', 'b', 'd', 'x', 'p'] ['n', 'y', 'q', 'k', 'm', 'b', 'x', 'z', 'c', 't', 'k', 'p', 'r', 's']
# r
# y
# n
# h
# z
# t
# k
# q
# o
# j
# m
# b
# d
# x
# p
# ['a', 'e', 'i', 'y', 's', 't', 'x', 'j', 'u', 'm', 'k', 'n', 'd', 'b', 'o'] ['n', 'd', 'b', 'o', 'a', 'i', 'e', 'y', 'j', 'u', 'm', 's', 't', 'g', 'h']
# a
# e
# i
# y
# s
# t
# x
# j
# u
# m
# k
# n
# d
# b
# o
# ['y', 'r', 'c', 'g', 'j', 'u', 'o', 'l', 's', 'p', 'k', 'v', 'z', 'n', 'h'] ['p', 'k', 'v', 'z', 'n', 'h', 'u', 'o', 'g', 'j', 'k', 'l']
# y
# r
# c
# g
# j
# u
# o
# l
# s
# p
# k
# v
# z
# n
# h
# ['p', 'e', 'y', 'a', 'j', 'z', 's', 'k', 'r', 'b', 'q', 'o', 'l', 'd', 'u'] ['o', 'l', 'd', 'u', 'j', 'k', 'b', 'z', 'p', 'e', 'y', 'a', 'c']
# p
# e
# y
# a
# j
# z
# s
# k
# r
# b
# q
# o
# l
# d
# u
# ['r', 's', 'f', 'h', 'm', 'o', 'q', 'j', 't', 'e', 'v', 'p', 'i', 'd', 'y'] ['j', 't', 'v', 'p', 'i', 'y', 'd', 'h', 'm', 'q', 'o']
# r
# s
# f
# h
# m
# o
# q
# j
# t
# e
# v
# p
# i
# d
# y
# ['s', 'l', 'm', 'h', 'v', 'b', 'f', 'j', 'p', 'd', 'k', 'e', 't', 'r', 'q'] ['k', 'e', 't', 'r', 'q', 's', 'l', 'm', 'n', 'p', 'q', 'o', 'u']
# s
# l
# m
# h
# v
# b
# f
# j
# p
# d
# k
# e
# t
# r
# q
# ['d', 'v', 'c', 'f', 'p', 's', 'l', 'g', 'h', 'j', 'a', 'm', 'y', 'o', 'e'] ['a', 'm', 'y', 'o', 'e', 'c', 'f', 'd', 'v', 'k', 'p', 'g']
# d
# v
# c
# f
# p
# s
# l
# g
# h
# j
# a
# m
# y
# o
# e
# ['x', 's', 'l', 'a', 'i', 'f', 'j', 'r', 'm', 'y', 'v', 'q', 'z', 'n', 'b'] ['y', 'v', 'q', 'z', 'n', 'b', 'l', 'a', 'i', 'f', 'x', 's', 'u', 'o']
# x
# s
# l
# a
# i
# f
# j
# r
# m
# y
# v
# q
# z
# n
# b
# ['r', 'x', 'k', 's', 'j', 'g', 'z', 'v', 'm', 'c', 'h', 'o', 'n', 'l', 'e'] ['m', 'c', 'h', 'o', 'n', 'l', 'e', 'r', 'x', 's', 'f', 'g']
# r
# x
# k
# s
# j
# g
# z
# v
# m
# c
# h
# o
# n
# l
# e
# ['x', 't', 'h', 'c', 'l', 'q', 'u', 'v', 'a', 'e', 's', 'b', 'p', 'z', 'g'] ['b', 'p', 'g', 'z', 'u', 'v', 'x', 'a', 'e', 's', 'r', 's', 't', 'g', 'y']
# x
# t
# h
# c
# l
# q
# u
# v
# a
# e
# s
# b
# p
# z
# g
# ['m', 'j', 'f', 'u', 's', 'v', 'b', 'd', 'o', 'g', 'i', 't', 'q', 'z', 'p'] ['t', 'i', 'q', 'z', 'p', 'm', 'j', 'd', 'o', 'g', 's', 'v', 'b', 'g', 'u']
# m
# j
# f
# u
# s
# v
# b
# d
# o
# g
# i
# t
# q
# z
# p
# ['e', 'g', 'i', 'o', 'u', 'p', 'a', 't', 'z', 'n', 'm', 'v', 'h', 's', 'x'] ['n', 'm', 'v', 'h', 's', 'x', 'p', 'a', 't', 'z', 'e', 'i', 'y', 'b']
# e
# g
# i
# o
# u
# p
# a
# t
# z
# n
# m
# v
# h
# s
# x
# ['s', 'm', 'p', 'd', 'i', 'g', 'a', 'r', 'q', 'v', 'o', 'x', 'u', 'b', 'k'] ['a', 'r', 'q', 'v', 'u', 'x', 'u', 'b', 'k', 's', 'm', 'p', 'd', 'i', 'e']
# s
# m
# p
# d
# i
# g
# a
# r
# q
# v
# o
# x
# u
# b
# k
# ['h', 'q', 'm', 'i', 'v', 'p', 'z', 'd', 'j', 'o', 'b', 't', 'n', 'g', 'l'] ['p', 'z', 'j', 'o', 'p', 'g', 'n', 'u', 'm', 'i', 'v', 'a']
# h
# q
# m
# i
# v
# p
# z
# d
# j
# o
# b
# t
# n
# g
# l
# ['k', 't', 'y', 'j', 'n', 'z', 'e', 'h', 'x', 'm', 's', 'g', 'u', 'o', 'c'] ['s', 'g', 'u', 'o', 'c', 'n', 'z', 'x', 'm', 'j', 't', 'p']
# k
# t
# y
# j
# n
# z
# e
# h
# x
# m
# s
# g
# u
# o
# c
# ['o', 'm', 't', 'z', 'j', 'f', 'b', 'r', 'u', 'k', 'i', 'l', 'q', 'p', 'n'] ['u', 'k', 'i', 'l', 'q', 'p', 'o', 'c', 't', 'b', 'm', 'n']
# o
# m
# t
# z
# j
# f
# b
# r
# u
# k
# i
# l
# q
# p
# n
# ['q', 'x', 'z', 'e', 'g', 'p', 's', 'v', 'i', 'u', 'r', 't', 'l', 'j', 'k'] ['s', 'v', 'i', 'u', 'r', 't', 'j', 'k', 'l', 'm', 'c', 'p', 'y', 'z']
# q
# x
# z
# e
# g
# p
# s
# v
# i
# u
# r
# t
# l
# j
# k
# ['q', 'k', 'a', 'p', 'n', 't', 'e', 'y', 'l', 'h', 'c', 'f', 'g', 'b', 'd'] ['h', 'c', 'f', 'g', 'p', 's', 'b', 'q', 't', 'e', 'y', 'b', 's']
# q
# k
# a
# p
# n
# t
# e
# y
# l
# h
# c
# f
# g
# b
# d
# ['f', 'p', 'm', 'd', 'z', 'a', 's', 'n', 'k', 'x', 't', 'l', 'b', 'q', 'j'] ['k', 't', 'x', 'l', 'm', 'n', 'b', 'j', 'p', 'q']
# f
# p
# m
# d
# z
# a
# s
# n
# k
# x
# t
# l
# b
# q
# j
# ['b', 'c', 'f', 'i', 'q', 'x', 'a', 'r', 'g', 'u', 'y', 'h', 'o', 'm', 'e'] ['g', 'u', 'y', 'h', 'o', 'm', 'e', 'a', 's', 't', 'x', 'c', 'j', 'i']
# b
# c
# f
# i
# q
# x
# a
# r
# g
# u
# y
# h
# o
# m
# e
# ['i', 'g', 'o', 'a', 'h', 'p', 'f', 'c', 'y', 'd', 'm', 'r', 'b', 't', 'l'] ['m', 'r', 'b', 't', 'l', 'i', 'g', 'l', 'o', 'x', 'c']
# i
# g
# o
# a
# h
# p
# f
# c
# y
# d
# m
# r
# b
# t
# l
# ['c', 'l', 'j', 'x', 'd', 'f', 'a', 'h', 'g', 'm', 'k', 't', 'n', 's', 'b'] ['m', 'n', 'k', 't', 's', 'l', 'b', 'a', 'y', 'p', 'i', 'e', 'u']
# c
# l
# j
# x
# d
# f
# a
# h
# g
# m
# k
# t
# n
# s
# b
# ['o', 'm', 'q', 't', 'u', 'n', 'r', 'k', 'y', 'g', 'b', 'e', 'v', 'f', 'x'] ['y', 'b', 't', 'e', 'i', 'x', 'r', 'm', 'l', 'k']
# o
# m
# q
# t
# u
# n
# r
# k
# y
# g
# b
# e
# v
# f
# x
# ['z', 'o', 'l', 'g', 'h', 'q', 'a', 'n', 'r', 'd', 'p', 'v', 'u', 'j', 'i'] ['a', 'n', 'd', 'r', 'b', 'u', 'v', 'y', 'j', 'b', 'm', 'z', 'o', 'y', 'g']
# z
# o
# l
# g
# h
# q
# a
# n
# r
# d
# p
# v
# u
# j
# i
# ['o', 'n', 'a', 'j', 'd', 'q', 'y', 'c', 'i', 'g', 'r', 'h', 'z', 'v', 'b'] ['i', 'g', 'v', 'h', 'r', 'z', 'b', 'o', 'm', 'a', 'p', 'u']
# o
# n
# a
# j
# d
# q
# y
# c
# i
# g
# r
# h
# z
# v
# b
# ['o', 'k', 'c', 'y', 'q', 'r', 'h', 'p', 't', 'n', 'd', 'j', 'v', 'e', 'z'] ['p', 't', 'n', 'd', 'j', 'z', 'p', 'v', 'o', 'k', 'a', 'c']
# o
# k
# c
# y
# q
# r
# h
# p
# t
# n
# d
# j
# v
# e
# z
# ['y', 'i', 'v', 'm', 'q', 'x', 'a', 'k', 'c', 'r', 'l', 'g', 's', 'e', 'd'] ['l', 'g', 'd', 'e', 's', 'y', 'k', 'a', 'c', 'y', 'i', 'v', 'j']
# y
# i
# v
# m
# q
# x
# a
# k
# c
# r
# l
# g
# s
# e
# d
# ['k', 'm', 'g', 'y', 'a', 'f', 't', 'i', 'n', 'x', 'c', 'e', 'o', 'b', 'j'] ['i', 'n', 'x', 'c', 'b', 'j', 'o', 'g', 'y', 'a', 't', 'p', 'q', 'n', 'm']
# k
# m
# g
# y
# a
# f
# t
# i
# n
# x
# c
# e
# o
# b
# j
# ['n', 't', 'e', 'b', 'x', 'm', 'v', 'i', 'a', 'g', 'q', 'j', 'l', 'p', 'z'] ['j', 'p', 'l', 'q', 'x', 'g', 'i', 'a', 't', 'v']
# n
# t
# e
# b
# x
# m
# v
# i
# a
# g
# q
# j
# l
# p
# z
# ['p', 'e', 'j', 'q', 'x', 'r', 'u', 'z', 'g', 's', 'f', 'a', 'i', 'm', 'n'] ['g', 's', 'a', 'i', 'f', 'm', 'n', 'r', 'u', 'x', 'y', 'c', 'f']
# p
# e
# j
# q
# x
# r
# u
# z
# g
# s
# f
# a
# i
# m
# n
# ['t', 'j', 'b', 'i', 'y', 'k', 'e', 'g', 'r', 'u', 'z', 'q', 'f', 'm', 'o'] ['r', 'u', 's', 'q', 'f', 'm', 'n', 'o', 'x', 'c', 'k', 'i', 'e']
# t
# j
# b
# i
# y
# k
# e
# g
# r
# u
# z
# q
# f
# m
# o
# ['b', 'r', 'p', 'h', 'q', 'z', 'i', 'd', 'x', 'v', 'o', 'e', 'f', 'a', 'g'] ['x', 'v', 'o', 'f', 'e', 'a', 'g', 'm', 'n', 'k', 'i', 'f', 'c', 'z']
# b
# r
# p
# h
# q
# z
# i
# d
# x
# v
# o
# e
# f
# a
# g
# ['u', 'a', 'c', 'd', 'r', 'b', 'h', 'm', 'v', 'l', 'z', 'y', 'k', 'j', 'o'] ['l', 'z', 'y', 'k', 'o', 'j', 'd', 'r', 'b', 'h', 'c', 'x']
# u
# a
# c
# d
# r
# b
# h
# m
# v
# l
# z
# y
# k
# j
# o
# ['c', 'q', 'r', 'p', 'x', 'e', 'a', 'k', 's', 'd', 'b', 'z', 'j', 'l', 'n'] ['z', 'j', 'l', 'n', 'd', 'b', 'x', 'r', 'j', 'k', 'o']
# c
# q
# r
# p
# x
# e
# a
# k
# s
# d
# b
# z
# j
# l
# n
# ['q', 'h', 'j', 'a', 'f', 'r', 's', 'k', 'n', 'm', 'v', 'z', 'b', 'c', 'u'] ['n', 'm', 'v', 'b', 'z', 'e', 'u', 'k', 'f', 'r']
# q
# h
# j
# a
# f
# r
# s
# k
# n
# m
# v
# z
# b
# c
# u
# ['d', 'h', 't', 'b', 'i', 'u', 'e', 'p', 'g', 'l', 'o', 'v', 'n', 's', 'k'] ['v', 'n', 's', 'k', 'd', 'h', 'b', 'u', 'i', 'x', 'a', 'b']
# d
# h
# t
# b
# i
# u
# e
# p
# g
# l
# o
# v
# n
# s
# k
# ['d', 'k', 'i', 'q', 'v', 'a', 'm', 'u', 'r', 'e', 'b', 'l', 'p', 'f', 'c'] ['b', 'l', 'p', 'f', 'c', 'v', 'a', 'm', 'u', 'r', 'i', 'q', 'd', 'k']
# d
# k
# i
# q
# v
# a
# m
# u
# r
# e
# b
# l
# p
# f
# c
# ['u', 'l', 'r', 'q', 'i', 'v', 'd', 'b', 'j', 't', 'm', 'f', 'g', 'h', 'y'] ['j', 'm', 'f', 'g', 't', 'h', 'y', 'e', 'u', 'l', 'r', 'i', 'q']
# u
# l
# r
# q
# i
# v
# d
# b
# j
# t
# m
# f
# g
# h
# y
# ['h', 'v', 'l', 't', 'y', 'i', 's', 'j', 'c', 'o', 'u', 'x', 'p', 'm', 'd'] ['j', 'c', 'h', 'o', 'x', 'p', 'd', 'y', 'i', 'e']
# h
# v
# l
# t
# y
# i
# s
# j
# c
# o
# u
# x
# p
# m
# d
# ['x', 'b', 'l', 'q', 'h', 'o', 'a', 'e', 'c', 'f', 'm', 'v', 'z', 'n', 's'] ['x', 'b', 'm', 'v', 'z', 'n', 'f', 'm', 'c', 'f', 'h', 'o', 'a', 'e']
# x
# b
# l
# q
# h
# o
# a
# e
# c
# f
# m
# v
# z
# n
# s
# ['d', 'v', 'b', 'o', 'g', 'e', 'x', 's', 'a', 't', 'k', 'm', 'c', 'j', 'p'] ['a', 't', 'm', 'k', 'j', 'c', 'p', 'd', 'v', 'f']
# d
# v
# b
# o
# g
# e
# x
# s
# a
# t
# k
# m
# c
# j
# p
# ['u', 'p', 'b', 'x', 'n', 'g', 'f', 'm', 'z', 'v', 'y', 'h', 's', 'e', 't'] ['m', 'z', 'v', 'h', 'y', 'e', 't', 'g', 'f', 'b', 'x', 'n']
# u
# p
# b
# x
# n
# g
# f
# m
# z
# v
# y
# h
# s
# e
# t
# ['c', 'h', 'e', 'v', 'b', 'x', 'i', 'r', 'q', 'p', 'l', 's', 't', 'm', 'o'] ['l', 's', 't', 'm', 'o', 'r', 'q', 's', 'b', 'x', 'i', 'n', 'f']
# c
# h
# e
# v
# b
# x
# i
# r
# q
# p
# l
# s
# t
# m
# o
# ['m', 'r', 'j', 'e', 'l', 'f', 'u', 's', 'i', 'p', 'g', 'b', 'z', 'd', 'y'] ['p', 'z', 'c', 'f', 'y', 'd', 'j', 'e', 'u', 'i', 'x']
# m
# r
# j
# e
# l
# f
# u
# s
# i
# p
# g
# b
# z
# d
# y
# ['d', 'y', 'q', 'k', 'a', 'j', 'v', 'i', 'c', 'u', 'f', 'o', 'g', 'm', 'x'] ['c', 'u', 'f', 'g', 'o', 'm', 'x', 'd', 'i', 'q', 'v', 'i']
# d
# y
# q
# k
# a
# j
# v
# i
# c
# u
# f
# o
# g
# m
# x
# ['c', 'x', 'l', 'n', 'o', 'g', 'z', 'a', 's', 'u', 'b', 'f', 'i', 'r', 'p'] ['a', 's', 'u', 'b', 'f', 'r', 'i', 'p', 'c', 'k', 'e']
# c
# x
# l
# n
# o
# g
# z
# a
# s
# u
# b
# f
# i
# r
# p
# ['x', 'g', 'y', 'v', 'm', 'a', 'j', 't', 'r', 'b', 'd', 'q', 'n', 'c', 'e'] ['r', 'b', 'e', 'q', 'n', 'c', 'b', 'a', 'p', 'a', 'v', 't']
# x
# g
# y
# v
# m
# a
# j
# t
# r
# b
# d
# q
# n
# c
# e
# ['u', 'a', 'g', 'p', 'n', 'e', 'd', 'm', 'c', 'z', 'v', 'j', 'b', 'h', 'i'] ['z', 'v', 'j', 'b', 'h', 'i', 'm', 'c', 'u', 'n', 'b', 'x']
# u
# a
# g
# p
# n
# e
# d
# m
# c
# z
# v
# j
# b
# h
# i
# ['v', 'r', 't', 'j', 'c', 'y', 'b', 'u', 'k', 'l', 'q', 'h', 'o', 'e', 'a'] ['u', 'q', 'l', 'k', 'h', 'o', 'e', 'a', 'u', 't', 'm']
# v
# r
# t
# j
# c
# y
# b
# u
# k
# l
# q
# h
# o
# e
# a
# ['m', 'i', 'f', 't', 'v', 'a', 'd', 'z', 'l', 's', 'r', 'n', 'y', 'h', 'o'] ['z', 'l', 'n', 'r', 'h', 'o', 'y', 'a', 'm', 'i', 'b', 'v']
# m
# i
# f
# t
# v
# a
# d
# z
# l
# s
# r
# n
# y
# h
# o
# ['f', 'e', 'r', 'x', 'd', 'j', 's', 'p', 'q', 'b', 'z', 'h', 'v', 'o', 'c'] ['s', 'b', 'k', 'l', 'y', 'h', 'o', 'v', 'z', 'e', 'g']
# f
# e
# r
# x
# d
# j
# s
# p
# q
# b
# z
# h
# v
# o
# c
# ['g', 'x', 'q', 'y', 'e', 'm', 'h', 'k', 'c', 'b', 't', 'r', 'z', 'j', 'f'] ['m', 'b', 'k', 'h', 'c', 'r', 'x', 'j', 'f', 'r', 'q', 'e']
# g
# x
# q
# y
# e
# m
# h
# k
# c
# b
# t
# r
# z
# j
# f
# ['v', 'i', 'h', 'a', 'k', 'g', 't', 'z', 'c', 'y', 's', 'n', 'd', 'e', 'p'] ['s', 'y', 'n', 'z', 'n', 'd', 'p', 'e', 'x', 'g', 't']
# v
# i
# h
# a
# k
# g
# t
# z
# c
# y
# s
# n
# d
# e
# p
# ['b', 'r', 'x', 'i', 'g', 'm', 'f', 'v', 'j', 'l', 'q', 'p', 't', 'h', 'o'] ['v', 'j', 'l', 'q', 'b', 't', 'h', 'o', 'x', 'i', 'a', 'k']
# b
# r
# x
# i
# g
# m
# f
# v
# j
# l
# q
# p
# t
# h
# o
# ['m', 'e', 'a', 'c', 'x', 'u', 'v', 'l', 'r', 'h', 'f', 'i', 'j', 'b', 'k'] ['v', 'l', 'r', 'i', 'f', 'b', 'j', 'k', 'l', 'o', 'x', 'h', 'a', 'e']
# m
# e
# a
# c
# x
# u
# v
# l
# r
# h
# f
# i
# j
# b
# k
# ['x', 'j', 'h', 'c', 'g', 'y', 'v', 't', 'p', 'u', 'z', 'a', 'm', 'b', 'i'] ['t', 'z', 'v', 'j', 'b', 'l', 'u', 'g', 'a', 'v', 'g']
# x
# j
# h
# c
# g
# y
# v
# t
# p
# u
# z
# a
# m
# b
# i
# ['f', 'v', 'y', 'p', 'j', 'i', 'd', 'u', 'q', 'z', 'a', 'k', 't', 'm', 'n'] ['v', 'i', 'p', 'q', 'z', 'v', 'j', 'm', 'b']
# f
# v
# y
# p
# j
# i
# d
# u
# q
# z
# a
# k
# t
# m
# n
# ['d', 'm', 'l', 'i', 'o', 'c', 'p', 'a', 't', 'f', 'q', 'y', 'j', 'b', 'k'] ['p', 'a', 't', 'd', 'm', 'd', 'v', 'i', 'y', 'j', 'b']
# d
# m
# l
# i
# o
# c
# p
# a
# t
# f
# q
# y
# j
# b
# k
# ['j', 's', 'o', 'a', 'h', 'i', 'k', 'e', 'n', 'x', 'q', 'z', 'u', 'r', 'm'] ['x', 'q', 'r', 'k', 'l', 'm', 'z', 'i', 'k', 'o', 'a', 'h']
# j
# s
# o
# a
# h
# i
# k
# e
# n
# x
# q
# z
# u
# r
# m
# ['f', 'a', 'i', 'p', 'd', 'r', 'c', 'e', 'x', 'l', 'z', 'g', 's', 'm', 'o'] ['l', 's', 'g', 'm', 'o', 'z', 'c', 'e', 'i', 'f']
# f
# a
# i
# p
# d
# r
# c
# e
# x
# l
# z
# g
# s
# m
# o
# ['p', 'e', 't', 'q', 'g', 's', 'l', 'b', 'r', 'h', 'n', 'o', 'c', 'z', 'v'] ['p', 'e', 't', 'l', 'm', 'r', 'n', 'q', 'o', 'p', 'z']
# p
# e
# t
# q
# g
# s
# l
# b
# r
# h
# n
# o
# c
# z
# v
# ['i', 'g', 'a', 'e', 'c', 'q', 't', 'z', 'j', 'u', 'y', 'b', 'v', 'p', 'f'] ['g', 'u', 'y', 'p', 'j', 'g', 'e', 'a', 'i']
# i
# g
# a
# e
# c
# q
# t
# z
# j
# u
# y
# b
# v
# p
# f
# ['l', 'b', 't', 'r', 'y', 'n', 'm', 'g', 'z', 'v', 'x', 'k', 'e', 'c', 'i'] ['v', 'x', 'i', 'c', 'k', 'b', 'i', 'g', 'f', 'h']
# l
# b
# t
# r
# y
# n
# m
# g
# z
# v
# x
# k
# e
# c
# i
# ['n', 'm', 'h', 'b', 'l', 'k', 't', 'c', 'i', 'r', 'v', 'a', 'd', 'g', 'q'] ['r', 'v', 'a', 'q', 'b', 'l', 'i', 'c', 'k', 'h', 'm', 'n', 'h', 'o']
# n
# m
# h
# b
# l
# k
# t
# c
# i
# r
# v
# a
# d
# g
# q
# ['b', 'h', 'a', 'j', 'y', 'n', 'g', 'l', 's', 'k', 'e', 'i', 'd', 'r', 'u'] ['g', 'l', 's', 'h', 'e', 'y', 'o', 'c', 'f', 'a']
# b
# h
# a
# j
# y
# n
# g
# l
# s
# k
# e
# i
# d
# r
# u
# ['d', 's', 'k', 'l', 'f', 'c', 'q', 'a', 'm', 't', 'e', 'u', 'h', 'g', 'y'] ['m', 't', 'h', 'e', 'y', 'u', 'i', 'd', 'r', 'a', 'g', 'f']
# d
# s
# k
# l
# f
# c
# q
# a
# m
# t
# e
# u
# h
# g
# y
# ['u', 'm', 't', 'h', 'a', 'i', 'x', 'q', 'o', 'k', 'j', 'f', 's', 'r', 'g'] ['j', 'r', 'f', 's', 'g', 'l', 'o', 'k', 'e', 'i']
# u
# m
# t
# h
# a
# i
# x
# q
# o
# k
# j
# f
# s
# r
# g
# ['a', 'f', 'm', 'c', 'd', 's', 'o', 'v', 'k', 'n', 'h', 'y', 'g', 'j', 't'] ['v', 'n', 'y', 'g', 'x', 'h', 'a', 'i', 'u', 'z']
# a
# f
# m
# c
# d
# s
# o
# v
# k
# n
# h
# y
# g
# j
# t
# ['h', 'a', 'k', 'o', 'b', 'g', 'q', 'n', 's', 'j', 't', 'l', 'r', 'x', 'p'] ['t', 'l', 'j', 'e', 'r', 'x', 'p', 'h', 'a', 'c', 'o', 'b', 'z']
# h
# a
# k
# o
# b
# g
# q
# n
# s
# j
# t
# l
# r
# x
# p
# ['m', 'c', 'g', 'k', 'r', 'u', 'x', 'd', 'j', 'n', 'p', 'h', 'b', 'f', 'e'] ['p', 'h', 'b', 'x', 'f', 'c', 'e', 'm', 'r', 'u', 'x', 'k']
# m
# c
# g
# k
# r
# u
# x
# d
# j
# n
# p
# h
# b
# f
# e
# ['h', 'c', 'l', 'y', 'a', 't', 'f', 'z', 'e', 'q', 'v', 'k', 'r', 'x', 'g'] ['z', 'f', 'c', 'k', 'u', 'l', 'f', 'j', 'm', 'h', 'c', 'a']
# h
# c
# l
# y
# a
# t
# f
# z
# e
# q
# v
# k
# r
# x
# g
# ['b', 'g', 'v', 'k', 'p', 'f', 'z', 'y', 'h', 'a', 'c', 'd', 'l', 'r', 's'] ['z', 'h', 'l', 'v', 'd', 'g', 'r', 'p', 'e']
# b
# g
# v
# k
# p
# f
# z
# y
# h
# a
# c
# d
# l
# r
# s
# ['i', 'y', 'd', 'n', 'k', 'f', 'r', 'q', 'g', 'u', 'p', 'e', 'l', 't', 'c'] ['g', 'u', 'y', 'p', 'l', 't', 'r', 'q', 's', 'd']
# i
# y
# d
# n
# k
# f
# r
# q
# g
# u
# p
# e
# l
# t
# c
# ['g', 'v', 'q', 'x', 'l', 'j', 'm', 't', 'o', 'p', 'n', 'z', 'd', 'h', 'k'] ['z', 'd', 'h', 'k', 'l', 'j', 'u', 'm', 'b', 'o', 'e', 'f']
# g
# v
# q
# x
# l
# j
# m
# t
# o
# p
# n
# z
# d
# h
# k
# ['v', 'q', 'm', 'i', 'r', 'y', 'j', 't', 'x', 'h', 'd', 'k', 'g', 'b', 'p'] ['h', 'd', 'g', 'p', 'j', 'c', 't', 'x', 'm', 'y', 'r', 'a']
# v
# q
# m
# i
# r
# y
# j
# t
# x
# h
# d
# k
# g
# b
# p
# ['q', 'b', 'x', 'n', 't', 'i', 'l', 'p', 'y', 'u', 'e', 'z', 'h', 'j', 'k'] ['q', 'b', 'x', 'i', 't', 'l', 'n']
# q
# b
# x
# n
# t
# i
# l
# p
# y
# u
# e
# z
# h
# j
# k
# ['b', 'i', 'p', 'q', 'd', 'x', 'z', 'u', 'o', 'm', 'j', 'f', 'v', 'k', 's'] ['b', 'i', 'p', 'q', 'd', 'x', 'z', 'u', 'o']
# b
# i
# p
# q
# d
# x
# z
# u
# o
# m
# j
# f
# v
# k
# s
# ['j', 'p', 'e', 'q', 'o', 'v', 'r', 'f', 'd', 'u', 'g', 'b', 'a', 'y', 't'] ['j', 'p', 'x', 'u', 'o', 'v', 'r']
# j
# p
# e
# q
# o
# v
# r
# f
# d
# u
# g
# b
# a
# y
# t
# ['n', 'q', 'y', 's', 'a', 'x', 'u', 'j', 'k', 'd', 'o', 'f', 'e', 'c', 't'] ['n', 'q', 'y', 'x', 'a', 's']
# n
# q
# y
# s
# a
# x
# u
# j
# k
# d
# o
# f
# e
# c
# t
# ['g', 'j', 'a', 's', 'h', 'u', 'd', 'i', 't', 'l', 'y', 'k', 'm', 'n', 'e'] ['g', 'j', 'a', 's', 'h', 'i', 'd', 'l']
# g
# j
# a
# s
# h
# u
# d
# i
# t
# l
# y
# k
# m
# n
# e
# ['c', 'm', 'h', 's', 'x', 'e', 'a', 'l', 'p', 'u', 'z', 'k', 'g', 'f', 'y'] ['c', 'm', 'h', 's', 'x', 'e', 'a']
# c
# m
# h
# s
# x
# e
# a
# l
# p
# u
# z
# k
# g
# f
# y
# ['q', 'i', 'z', 'a', 't', 'f', 'g', 'd', 'u', 'p', 'n', 'e', 'c', 'm', 'v'] ['q', 'i', 'z', 'a', 't', 'f']
# q
# i
# z
# a
# t
# f
# g
# d
# u
# p
# n
# e
# c
# m
# v
# ['s', 'y', 'j', 'u', 'h', 'l', 'f', 'c', 'a', 'g', 'm', 'q', 'e', 'p', 'k'] ['s', 'y', 'j', 'u', 'k', 'l', 'f', 'c']
# s
# y
# j
# u
# h
# l
# f
# c
# a
# g
# m
# q
# e
# p
# k
# ['y', 'g', 'l', 'p', 'i', 'm', 'j', 't', 'n', 'e', 'r', 'u', 'z', 'h', 's'] ['h', 'g', 's', 'p', 'i', 'm', 'j', 'c']
# y
# g
# l
# p
# i
# m
# j
# t
# n
# e
# r
# u
# z
# h
# s
# ['q', 'v', 'x', 'h', 'd', 'o', 's', 'i', 'l', 'e', 'g', 'm', 'k', 'f', 'j'] ['q', 'v', 'x', 'h', 'd', 'o']
# q
# v
# x
# h
# d
# o
# s
# i
# l
# e
# g
# m
# k
# f
# j
# ['r', 'a', 'u', 'y', 'm', 'o', 'v', 'p', 's', 'b', 'f', 'k', 'n', 'g', 'z'] ['r', 'a', 'u', 'y', 'm', 'o', 'v', 'p', 's']
# r
# a
# u
# y
# m
# o
# v
# p
# s
# b
# f
# k
# n
# g
# z
# ['z', 'l', 'j', 'x', 'u', 'q', 's', 'i', 'o', 'n', 'k', 'y', 'h', 'c', 'm'] ['z', 'j', 'l', 'x', 'q', 'y', 's']
# z
# l
# j
# x
# u
# q
# s
# i
# o
# n
# k
# y
# h
# c
# m
# ['d', 'u', 'x', 'm', 'g', 'o', 'e', 'h', 'z', 'v', 's', 'l', 'j', 'a', 'b'] ['d', 'u', 'x', 'm', 'g', 'h', 'o', 'y', 'e', 'z']
# d
# u
# x
# m
# g
# o
# e
# h
# z
# v
# s
# l
# j
# a
# b
# ['m', 'q', 'z', 'a', 'g', 't', 's', 'e', 'k', 'f', 'd', 'x', 'j', 'v', 'h'] ['m', 'q', 'z', 'a', 'g', 't', 's']
# m
# q
# z
# a
# g
# t
# s
# e
# k
# f
# d
# x
# j
# v
# h
# ['q', 'r', 'b', 'j', 'n', 's', 'e', 'g', 'c', 'd', 'k', 'f', 'u', 't', 'h'] ['q', 'r', 'b', 'j', 'n', 's', 'e', 'g', 'k']
# q
# r
# b
# j
# n
# s
# e
# g
# c
# d
# k
# f
# u
# t
# h
# ['a', 'o', 'd', 'f', 'j', 'k', 'z', 'u', 'q', 'b', 'v', 'y', 't', 'i', 'r'] ['a', 'o', 'd', 'f', 'j', 'k', 'z', 'u']
# a
# o
# d
# f
# j
# k
# z
# u
# q
# b
# v
# y
# t
# i
# r
# ['v', 'u', 'a', 'm', 'i', 'd', 't', 'b', 'c', 'p', 'q', 'n', 'j', 'y', 'r'] ['v', 'u', 'a', 'm', 'i', 'd', 't', 'b', 'p', 'c']
# v
# u
# a
# m
# i
# d
# t
# b
# c
# p
# q
# n
# j
# y
# r
# ['d', 'c', 'v', 'p', 'r', 'z', 'k', 'j', 'l', 'f', 's', 'x', 'b', 'h', 'g'] ['d', 'c', 'v', 'p', 'r', 'z', 'q', 'j']
# d
# c
# v
# p
# r
# z
# k
# j
# l
# f
# s
# x
# b
# h
# g
# ['g', 's', 'f', 'b', 'h', 'd', 't', 'z', 'u', 'r', 'e', 'k', 'c', 'a', 'p'] ['g', 's', 'f', 'b', 'p', 'v', 'j']
# g
# s
# f
# b
# h
# d
# t
# z
# u
# r
# e
# k
# c
# a
# p
# ['z', 'j', 'p', 't', 'f', 'm', 'x', 'v', 'b', 'd', 'y', 'e', 'h', 'a', 'o'] ['z', 'j', 'b', 't', 'f']
# z
# j
# p
# t
# f
# m
# x
# v
# b
# d
# y
# e
# h
# a
# o
# ['p', 'z', 'o', 'q', 's', 'm', 'r', 'k', 't', 'h', 'c', 'e', 'f', 'b', 'i'] ['p', 'z', 'g', 'o', 's']
# p
# z
# o
# q
# s
# m
# r
# k
# t
# h
# c
# e
# f
# b
# i
# ['f', 'd', 'o', 'i', 'e', 'j', 'r', 'k', 'z', 'b', 'u', 's', 'l', 'h', 'g'] ['f', 'd', 'o', 'i', 'e', 'j', 'k', 'r']
# f
# d
# o
# i
# e
# j
# r
# k
# z
# b
# u
# s
# l
# h
# g
# ['m', 'x', 'j', 'o', 'r', 'e', 'p', 'v', 'y', 'z', 'k', 'f', 'g', 'a', 'l'] ['m', 'x', 'j', 'o', 'r', 'e']
# m
# x
# j
# o
# r
# e
# p
# v
# y
# z
# k
# f
# g
# a
# l
# ['o', 'z', 'k', 'i', 'h', 'r', 'v', 'j', 't', 'q', 'c', 'a', 'm', 'u', 's'] ['o', 'x', 'h', 'i', 'j', 'k', 'r', 's']
# o
# z
# k
# i
# h
# r
# v
# j
# t
# q
# c
# a
# m
# u
# s
# ['y', 'e', 'r', 'z', 'v', 't', 'o', 'm', 'b', 'f', 'q', 'p', 'n', 'x', 'g'] ['y', 'e', 'r', 'z', 'v', 't']
# y
# e
# r
# z
# v
# t
# o
# m
# b
# f
# q
# p
# n
# x
# g
# ['n', 'h', 'd', 'g', 'a', 'o', 'm', 'c', 'u', 't', 'l', 'z', 's', 'r', 'e'] ['n', 'h', 'd', 'g', 'a', 'o', 'm', 'c', 'u']
# n
# h
# d
# g
# a
# o
# m
# c
# u
# t
# l
# z
# s
# r
# e
# ['a', 'g', 'b', 's', 'k', 't', 'o', 'f', 'j', 'u', 'x', 'm', 'p', 'z', 'v'] ['a', 'g', 'b', 's', 'k', 't']
# a
# g
# b
# s
# k
# t
# o
# f
# j
# u
# x
# m
# p
# z
# v
# ['x', 'q', 'o', 'z', 'm', 'i', 'v', 'l', 'b', 'p', 's', 'f', 'a', 'e', 'j'] ['x', 'q', 'u', 'o', 'y', 'z']
# x
# q
# o
# z
# m
# i
# v
# l
# b
# p
# s
# f
# a
# e
# j
# ['n', 'i', 'e', 'm', 'z', 'g', 'h', 'u', 's', 'x', 'q', 'y', 'p', 'o', 'd'] ['n', 'i', 'e', 'm', 'z', 'g', 'h', 'u']
# n
# i
# e
# m
# z
# g
# h
# u
# s
# x
# q
# y
# p
# o
# d
# ['i', 'j', 'k', 'm', 'h', 'a', 't', 'x', 'n', 'g', 'o', 'f', 'c', 'v', 'q'] ['i', 'j', 'h', 'm', 'o']
# i
# j
# k
# m
# h
# a
# t
# x
# n
# g
# o
# f
# c
# v
# q
# ['f', 'i', 'z', 'a', 'v', 'p', 's', 'h', 't', 'q', 'm', 'g', 'y', 'r', 'k'] ['f', 'i', 'z', 'a', 'v', 'h', 't', 's']
# f
# i
# z
# a
# v
# p
# s
# h
# t
# q
# m
# g
# y
# r
# k
# ['x', 'e', 's', 'c', 'o', 'b', 'z', 'q', 'h', 'l', 'k', 'y', 'd', 'u', 'm'] ['x', 'e', 's', 'c', 'o', 'b', 'z', 'h', 'u']
# x
# e
# s
# c
# o
# b
# z
# q
# h
# l
# k
# y
# d
# u
# m
# ['g', 'v', 't', 'y', 'r', 'f', 'i', 'u', 'l', 'n', 'h', 'o', 'e', 'm', 'x'] ['g', 'v', 't', 'y', 'r', 'f']
# g
# v
# t
# y
# r
# f
# i
# u
# l
# n
# h
# o
# e
# m
# x
# ['p', 'z', 'e', 'y', 'f', 'm', 'l', 'h', 's', 'g', 't', 'u', 'q', 'a', 'x'] ['p', 'z', 'e', 'y', 'f', 'm', 'l']
# p
# z
# e
# y
# f
# m
# l
# h
# s
# g
# t
# u
# q
# a
# x
# ['f', 'n', 't', 'e', 'c', 'r', 'm', 'i', 'd', 'k', 'p', 'o', 'l', 'u', 'v'] ['f', 'n', 't', 'e', 'c', 'r', 'm', 'i', 'd']
# f
# n
# t
# e
# c
# r
# m
# i
# d
# k
# p
# o
# l
# u
# v
# ['v', 'e', 'm', 't', 'x', 'i', 'q', 'o', 'g', 'u', 'z', 'h', 'k', 'j', 's'] ['v', 'e', 'm', 't', 'x', 'i', 'q', 'o', 'g', 'u']
# v
# e
# m
# t
# x
# i
# q
# o
# g
# u
# z
# h
# k
# j
# s
# ['r', 'g', 'k', 'u', 'f', 'q', 'e', 'z', 'm', 'o', 'y', 'a', 't', 'p', 's'] ['r', 'g', 'k', 'u', 'f', 'q']
# r
# g
# k
# u
# f
# q
# e
# z
# m
# o
# y
# a
# t
# p
# s
# ['c', 'm', 'd', 'z', 'f', 'y', 'i', 'p', 'n', 'h', 't', 'g', 'e', 'a', 'v'] ['c', 'm', 'd', 'z', 'f', 'y', 'i']
# c
# m
# d
# z
# f
# y
# i
# p
# n
# h
# t
# g
# e
# a
# v
# ['m', 'l', 'd', 's', 'f', 'a', 'p', 'q', 'g', 'z', 'y', 'j', 'v', 'b', 'o'] ['m', 'l', 'd', 's', 'f', 'a', 'p', 'q']
# m
# l
# d
# s
# f
# a
# p
# q
# g
# z
# y
# j
# v
# b
# o
# ['r', 'e', 'b', 'i', 't', 'y', 'm', 'a', 'h', 's', 'o', 'n', 'u', 'd', 'v'] ['r', 'e', 'b', 'i', 't', 'y', 'm', 'a', 'h']
# r
# e
# b
# i
# t
# y
# m
# a
# h
# s
# o
# n
# u
# d
# v
# ['see', 'you', 'our', 'boy', 'any', 'yes', 'him', 'out', 'has', 'met', 'act', 'bed', 'for', 'per', 'new'] ['see', 'you', 'our', 'boy', 'any', 'yes', 'him']
# see
# you
# our
# boy
# any
# yes
# him
# out
# has
# met
# act
# bed
# for
# per
# new
# ['met', 'per', 'law', 'far', 'his', 'see', 'few', 'she', 'one', 'job', 'off', 'win', 'out', 'hot', 'add'] ['met', 'per', 'law', 'far', 'his', 'see']
# met
# per
# law
# far
# his
# see
# few
# she
# one
# job
# off
# win
# out
# hot
# add
# ['air', 'get', 'day', 'ago', 'act', 'eat', 'his', 'set', 'pay', 'ask', 'why', 'yet', 'but', 'you', 'won'] ['air', 'get', 'day', 'ago', 'him']
# air
# get
# day
# ago
# act
# eat
# his
# set
# pay
# ask
# why
# yet
# but
# you
# won
# ['how', 'not', 'art', 'job', 'six', 'war', 'buy', 'far', 'all', 'air', 'ask', 'age', 'cup', 'set', 'few'] ['how', 'not', 'art', 'job', 'six', 'war']
# how
# not
# art
# job
# six
# war
# buy
# far
# all
# air
# ask
# age
# cup
# set
# few
# ['hey', 'led', 'ask', 'bit', 'ago', 'boy', 'met', 'run', 'far', 'dog', 'hit', 'tax', 'use', 'mom', 'son'] ['hey', 'led', 'ask', 'bit', 'ago']
# hey
# led
# ask
# bit
# ago
# boy
# met
# run
# far
# dog
# hit
# tax
# use
# mom
# son
# ['why', 'say', 'ago', 'art', 'buy', 'hit', 'him', 'out', 'big', 'bit', 'tax', 'day', 'son', 'yes', 'saw'] ['why', 'say', 'hello', 'art', 'buy', 'hit']
# why
# say
# ago
# art
# buy
# hit
# him
# out
# big
# bit
# tax
# day
# son
# yes
# saw
# ['all', 'way', 'say', 'dog', 'due', 'and', 'bit', 'car', 'put', 'die', 'yet', 'may', 'saw', 'bad', 'are'] ['all', 'way', 'say', 'art', 'due', 'dog']
# all
# way
# say
# dog
# due
# and
# bit
# car
# put
# die
# yet
# may
# saw
# bad
# are
# ['bad', 'six', 'low', 'try', 'his', 'key', 'she', 'way', 'due', 'out', 'fun', 'use', 'saw', 'war', 'red'] ['bad', 'six', 'hit', 'guy', 'met', 'she']
# bad
# six
# low
# try
# his
# key
# she
# way
# due
# out
# fun
# use
# saw
# war
# red
# ['and', 'its', 'own', 'sex', 'hot', 'die', 'off', 'his', 'did', 'put', 'cut', 'the', 'buy', 'how', 'boy'] ['and', 'its', 'own', 'hit', 'six', 'his', 'she']
# and
# its
# own
# sex
# hot
# die
# off
# his
# did
# put
# cut
# the
# buy
# how
# boy
# ['men', 'yes', 'say', 'led', 'son', 'why', 'out', 'law', 'car', 'mom', 'day', 'new', 'she', 'let', 'boy'] ['men', 'yes', 'say', 'led', 'son']
# men
# yes
# say
# led
# son
# why
# out
# law
# car
# mom
# day
# new
# she
# let
# boy
# ['has', 'six', 'off', 'hit', 'put', 'per', 'did', 'bit', 'run', 'him', 'guy', 'the', 'own', 'out', 'age'] ['has', 'six', 'off', 'hit', 'put', 'per']
# has
# six
# off
# hit
# put
# per
# did
# bit
# run
# him
# guy
# the
# own
# out
# age
# ['cup', 'per', 'six', 'but', 'two', 'hey', 'bit', 'any', 'who', 'put', 'see', 'and', 'way', 'yet', 'can'] ['cup', 'per', 'six', 'but', 'say', 'hey']
# cup
# per
# six
# but
# two
# hey
# bit
# any
# who
# put
# see
# and
# way
# yet
# can
# ['war', 'has', 'the', 'saw', 'too', 'try', 'son', 'non', 'per', 'all', 'are', 'top', 'one', 'may', 'who'] ['war', 'has', 'the', 'saw', 'too', 'try', 'son']
# war
# has
# the
# saw
# too
# try
# son
# non
# per
# all
# are
# top
# one
# may
# who
# ['few', 'win', 'per', 'mom', 'cup', 'due', 'but', 'own', 'eat', 'war', 'are', 'son', 'you', 'get', 'our'] ['few', 'win', 'per', 'mom', 'cup', 'due', 'but']
# few
# win
# per
# mom
# cup
# due
# but
# own
# eat
# war
# are
# son
# you
# get
# our
# ['was', 'how', 'hey', 'tax', 'any', 'bad', 'all', 'fun', 'war', 'man', 'two', 'dog', 'can', 'per', 'won'] ['was', 'how', 'hey', 'tax', 'any', 'bad']
# was
# how
# hey
# tax
# any
# bad
# all
# fun
# war
# man
# two
# dog
# can
# per
# won
# ['man', 'ago', 'due', 'way', 'war', 'men', 'one', 'far', 'tax', 'hit', 'not', 'now', 'let', 'oil', 'saw'] ['man', 'ago', 'due', 'way', 'war', 'one']
# man
# ago
# due
# way
# war
# men
# one
# far
# tax
# hit
# not
# now
# let
# oil
# saw
# ['her', 'are', 'new', 'got', 'boy', 'one', 'get', 'you', 'has', 'guy', 'son', 'yet', 'hit', 'cut', 'big'] ['her', 'are', 'who', 'new', 'boy', 'one', 'get']
# her
# are
# new
# got
# boy
# one
# get
# you
# has
# guy
# son
# yet
# hit
# cut
# big
# ['run', 'win', 'can', 'led', 'did', 'yes', 'cut', 'you', 'him', 'end', 'one', 'few', 'ago', 'men', 'non'] ['run', 'win', 'can', 'yes', 'led', 'did']
# run
# win
# can
# led
# did
# yes
# cut
# you
# him
# end
# one
# few
# ago
# men
# non
# ['add', 'got', 'buy', 'for', 'oil', 'eat', 'who', 'new', 'red', 'had', 'six', 'key', 'saw', 'run', 'bed'] ['add', 'got', 'buy', 'for', 'oil']
# add
# got
# buy
# for
# oil
# eat
# who
# new
# red
# had
# six
# key
# saw
# run
# bed
# ['met', 'the', 'man', 'saw', 'lot', 'war', 'own', 'guy', 'out', 'big', 'hit', 'may', 'now', 'car', 'off'] ['met', 'the', 'man', 'saw', 'lot', 'war', 'own']
# met
# the
# man
# saw
# lot
# war
# own
# guy
# out
# big
# hit
# may
# now
# car
# off
# ['c', 'l', 'b', 'x', 'g', 'q', 'u', 't', 'f', 'i', 'e', 'm', 'r', 'o', 'j'] ['c', 'l', 'b', 'x']
# c
# l
# b
# x
# g
# q
# u
# t
# f
# i
# e
# m
# r
# o
# j
# ['t', 'q', 'h', 'k', 'x', 'm', 'u', 'b', 'z', 'f', 'o', 'j', 'y', 'v', 'c'] ['t', 'h', 'q', 'd']
# t
# q
# h
# k
# x
# m
# u
# b
# z
# f
# o
# j
# y
# v
# c
# ['l', 'r', 'd', 'b', 'u', 'v', 'e', 'a', 'k', 'y', 'c', 'g', 'q', 'o', 'i'] ['l', 'b', 'r', 'd']
# l
# r
# d
# b
# u
# v
# e
# a
# k
# y
# c
# g
# q
# o
# i
# ['f', 'y', 'p', 'e', 'x', 's', 'o', 'j', 'r', 'g', 'z', 'v', 'q', 'c', 'b'] ['f', 'y', 'p', 'e', 'x', 's']
# f
# y
# p
# e
# x
# s
# o
# j
# r
# g
# z
# v
# q
# c
# b
# ['s', 'c', 'k', 'v', 'a', 'j', 'x', 'h', 'd', 'u', 'r', 'y', 'n', 'f', 'l'] ['s', 'c', 'k', 'v']
# s
# c
# k
# v
# a
# j
# x
# h
# d
# u
# r
# y
# n
# f
# l
# ['t', 'u', 'q', 's', 'a', 'p', 'l', 'd', 'v', 'f', 'i', 'n', 'c', 'h', 'k'] ['t', 'u', 'q', 's', 'a', 'p']
# t
# u
# q
# s
# a
# p
# l
# d
# v
# f
# i
# n
# c
# h
# k
# ['x', 'c', 'p', 'a', 'y', 'd', 'b', 't', 'j', 'u', 'q', 'z', 'g', 'f', 'h'] ['x', 'c', 'a', 'p', 'y']
# x
# c
# p
# a
# y
# d
# b
# t
# j
# u
# q
# z
# g
# f
# h
# ['b', 'a', 'q', 'k', 'd', 'h', 's', 'm', 'j', 'z', 'x', 'u', 'e', 'n', 'i'] ['b', 'a', 'q', 'k', 'd', 'h']
# b
# a
# q
# k
# d
# h
# s
# m
# j
# z
# x
# u
# e
# n
# i
# ['n', 'b', 'x', 'p', 'q', 'o', 'l', 'j', 'c', 'a', 'z', 'v', 'k', 'h', 'r'] ['n', 'x', 'p', 'q']
# n
# b
# x
# p
# q
# o
# l
# j
# c
# a
# z
# v
# k
# h
# r
# ['m', 'x', 's', 'p', 'd', 'u', 't', 'q', 'z', 'i', 'g', 'l', 'f', 'b', 'h'] ['m', 'x', 'p', 's', 'd']
# m
# x
# s
# p
# d
# u
# t
# q
# z
# i
# g
# l
# f
# b
# h
# ['b', 'a', 'h', 'z', 'd', 'e', 'x', 'l', 'q', 'v', 'c', 'f', 'm', 'y', 'j'] ['b', 'a', 'h', 'z', 'd', 'e']
# b
# a
# h
# z
# d
# e
# x
# l
# q
# v
# c
# f
# m
# y
# j
# ['i', 'b', 'u', 't', 'm', 'v', 'h', 'q', 'g', 'a', 'k', 'z', 'j', 'r', 'p'] ['i', 'b', 'u', 't', 'm', 'v', 'h']
# i
# b
# u
# t
# m
# v
# h
# q
# g
# a
# k
# z
# j
# r
# p
# ['p', 'j', 'z', 'h', 's', 'u', 'g', 'd', 'q', 'l', 'm', 'o', 't', 'y', 'a'] ['p', 'j', 'z', 'h']
# p
# j
# z
# h
# s
# u
# g
# d
# q
# l
# m
# o
# t
# y
# a
# ['f', 'i', 'm', 'r', 'b', 'd', 's', 'k', 'q', 'o', 'v', 'x', 'a', 'l', 'c'] ['f', 'i', 'm', 'r', 'b', 'd', 's']
# f
# i
# m
# r
# b
# d
# s
# k
# q
# o
# v
# x
# a
# l
# c
# ['i', 't', 'x', 's', 'y', 'e', 'r', 'k', 'h', 'f', 'a', 'l', 'n', 'q', 'z'] ['i', 't', 'x', 's', 'y', 'e', 'r', 'k']
# i
# t
# x
# s
# y
# e
# r
# k
# h
# f
# a
# l
# n
# q
# z
# ['p', 'f', 'l', 's', 'q', 'm', 'b', 'e', 'j', 'd', 'r', 'o', 'h', 'a', 'c'] ['p', 'f', 'm', 'l', 'q']
# p
# f
# l
# s
# q
# m
# b
# e
# j
# d
# r
# o
# h
# a
# c
# ['z', 'x', 'g', 'e', 'k', 'l', 'v', 'y', 'd', 'f', 'q', 'c', 'a', 't', 'p'] ['z', 'x', 'g', 'e', 'k', 'l']
# z
# x
# g
# e
# k
# l
# v
# y
# d
# f
# q
# c
# a
# t
# p
# ['i', 'g', 'l', 'u', 'm', 'b', 'e', 'n', 'q', 'o', 'x', 'd', 'c', 'h', 'p'] ['i', 'g', 'l', 'u', 'm', 'b', 'e', 'n']
# i
# g
# l
# u
# m
# b
# e
# n
# q
# o
# x
# d
# c
# h
# p
# ['n', 'f', 'z', 'i', 'e', 'c', 'a', 'u', 'd', 'b', 'g', 'o', 'q', 'p', 'x'] ['n', 'f', 'z', 'i', 'e', 'r']
# n
# f
# z
# i
# e
# c
# a
# u
# d
# b
# g
# o
# q
# p
# x
# ['a', 'p', 'i', 'x', 'u', 'e', 'j', 'o', 'd', 'y', 't', 'c', 'l', 'v', 'r'] ['a', 'p', 'i', 'x', 'u', 'e', 'j', 'o']
# a
# p
# i
# x
# u
# e
# j
# o
# d
# y
# t
# c
# l
# v
# r
